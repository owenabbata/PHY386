# %% [markdown]
# <a href="https://colab.research.google.com/github/ubsuny/PHY386/blob/Homework2026/2026/FinalProject/Final_02_RingOfFire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Final Project — Topic 2: Ring of Fire from Earthquake Data (42 pts)
#
# ## Learning Outcomes
# - Query a public geophysical database (USGS ComCat) with the `libcomcat` Python client — same programmatic spirit as `astroquery` in HW6.
# - Engineer features (lat, lon, depth, magnitude) from a real-world catalog.
# - Label events by geographic membership in the Pacific Ring of Fire.
# - Train k-Nearest Neighbors and Random Forest classifiers; compare them quantitatively.
# - Connect the feature importance back to the physics of subduction zones and mid-ocean ridges.
# - Visualize decision regions on a world map with `cartopy`.

# %% [markdown]
# ## GitHub Workflow
# Fork → `yourname-final` → pull request into `Homework2026`. Reviewer `@laserlab`, milestone `Final-2026`. See [`pull_request_template_Final.md`](pull_request_template_Final.md).

# %% [markdown]
# ## Background: The Ring of Fire
#
# The **Pacific Ring of Fire** is the horseshoe-shaped belt of tectonic activity around the Pacific Ocean — the convergent-plate boundaries where the Pacific, Nazca, Cocos, and Juan de Fuca plates subduct beneath the surrounding continental and oceanic plates. About **90% of the world's earthquakes** and most of its volcanoes occur in this belt.
#
# Two physical predictions we can test:
# 1. **Location dominates.** Earthquakes cluster along plate boundaries. A classifier trained only on (latitude, longitude) should already get most of the signal.
# 2. **Depth distinguishes.** Subduction zones produce earthquakes at all depths, from shallow (<70 km) at the trench to deep-focus (>300 km) along the Wadati–Benioff zone. Mid-ocean ridges, in contrast, only produce shallow quakes. So including **depth** as a feature should separate subduction from other seismic activity.
#
# You will check both.
#
# The data come from the **USGS Comprehensive Catalog (ComCat)** via the official `libcomcat` Python package. Think of it as `astroquery` for earthquakes.

# %%
# Required packages (uncomment for Colab or fresh environment):
#%pip install libcomcat-python cartopy scikit-learn --quiet

# %pip install --upgrade pip
# %pip install usgs-libcomcat
# Out:
# Requirement already satisfied: pip in /workspaces/PHY386/.venv/lib/python3.12/site-packages (26.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Collecting usgs-libcomcat
#   Downloading usgs_libcomcat-2.1.12-py3-none-any.whl.metadata (5.5 kB)
# Collecting esi_utils_colors>=1.0.3 (from usgs-libcomcat)
#   Downloading esi_utils_colors-1.0.5-py3-none-any.whl.metadata (3.4 kB)
# Collecting esi_utils_geo (from usgs-libcomcat)
#   Downloading esi_utils_geo-0.9.11-py3-none-any.whl.metadata (3.1 kB)
# Collecting esi-utils-rupture (from usgs-libcomcat)
#   Downloading esi_utils_rupture-1.0.9-py3-none-any.whl.metadata (3.5 kB)
# Collecting esi_utils_time (from usgs-libcomcat)
#   Downloading esi_utils_time-1.0.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting esi_utils_io (from usgs-libcomcat)
#   Downloading esi_utils_io-1.1.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting fiona>=1.8.20 (from usgs-libcomcat)
#   Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
# Collecting geopy>=2.1.0 (from usgs-libcomcat)
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting h5py (from usgs-libcomcat)
#   Downloading h5py-3.16.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting numba (from usgs-libcomcat)
#   Downloading numba-0.65.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.21 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from usgs-libcomcat) (2.4.4)
# Collecting obspy>=1.2.1 (from usgs-libcomcat)
#   Downloading obspy-1.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: pandas>=1.3.3 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from usgs-libcomcat) (3.0.2)
# Collecting openpyxl>=3.0.6 (from usgs-libcomcat)
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting requests (from usgs-libcomcat)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting urllib3<1.27,>=1.25.4 (from usgs-libcomcat)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Collecting xlsxwriter>=3.0.1 (from usgs-libcomcat)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: matplotlib>=3.1.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from esi_utils_colors>=1.0.3->usgs-libcomcat) (3.10.9)
# Collecting attrs>=19.2.0 (from fiona>=1.8.20->usgs-libcomcat)
#   Downloading attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: certifi in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from fiona>=1.8.20->usgs-libcomcat) (2026.4.22)
# Collecting click~=8.0 (from fiona>=1.8.20->usgs-libcomcat)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting click-plugins>=1.0 (from fiona>=1.8.20->usgs-libcomcat)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.20->usgs-libcomcat)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting geographiclib<3,>=1.52 (from geopy>=2.1.0->usgs-libcomcat)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (26.2)
# Requirement already satisfied: pillow>=8 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.7 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from obspy>=1.2.1->usgs-libcomcat) (1.17.1)
# Collecting lxml (from obspy>=1.2.1->usgs-libcomcat)
#   Downloading lxml-6.1.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Collecting setuptools (from obspy>=1.2.1->usgs-libcomcat)
#   Downloading setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting sqlalchemy>=1.4 (from obspy>=1.2.1->usgs-libcomcat)
#   Downloading sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: decorator in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from obspy>=1.2.1->usgs-libcomcat) (5.2.1)
# Collecting et-xmlfile (from openpyxl>=3.0.6->usgs-libcomcat)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.0->esi_utils_colors>=1.0.3->usgs-libcomcat) (1.17.0)
# Collecting greenlet>=1 (from sqlalchemy>=1.4->obspy>=1.2.1->usgs-libcomcat)
#   Downloading greenlet-3.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy>=1.4->obspy>=1.2.1->usgs-libcomcat)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting geopandas (from esi_utils_geo->usgs-libcomcat)
#   Downloading geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting scp>=0.14.0 (from esi_utils_geo->usgs-libcomcat)
#   Downloading scp-0.15.0-py2.py3-none-any.whl.metadata (4.3 kB)
# Collecting paramiko>=2.10.0 (from esi_utils_geo->usgs-libcomcat)
#   Downloading paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting bcrypt>=3.2 (from paramiko>=2.10.0->esi_utils_geo->usgs-libcomcat)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting cryptography>=3.3 (from paramiko>=2.10.0->esi_utils_geo->usgs-libcomcat)
#   Downloading cryptography-48.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Collecting invoke>=2.0 (from paramiko>=2.10.0->esi_utils_geo->usgs-libcomcat)
#   Downloading invoke-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting pynacl>=1.5 (from paramiko>=2.10.0->esi_utils_geo->usgs-libcomcat)
#   Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Collecting cffi>=2.0.0 (from cryptography>=3.3->paramiko>=2.10.0->esi_utils_geo->usgs-libcomcat)
#   Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.3->paramiko>=2.10.0->esi_utils_geo->usgs-libcomcat)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting charset_normalizer<4,>=2 (from requests->usgs-libcomcat)
#   Downloading charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests->usgs-libcomcat)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting pytz>=2021.3 (from esi_utils_io->usgs-libcomcat)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting defusedxml>=0.7.1 (from esi-utils-rupture->usgs-libcomcat)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting esi-extern-openquake>=1.0.0 (from esi-utils-rupture->usgs-libcomcat)
#   Downloading esi_extern_openquake-1.0.2-py3-none-any.whl.metadata (615 bytes)
# Collecting esi-utils-vectors>=1.0.0 (from esi-utils-rupture->usgs-libcomcat)
#   Downloading esi_utils_vectors-1.0.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting openquake.engine>=3.23 (from esi-utils-rupture->usgs-libcomcat)
#   Downloading openquake_engine-3.25.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: psutil>=5.9 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from esi-utils-rupture->usgs-libcomcat) (7.2.2)
# Requirement already satisfied: pyproj>=2.6.1 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from esi-utils-rupture->usgs-libcomcat) (3.7.2)
# Collecting toml>=0.10 (from esi-utils-rupture->usgs-libcomcat)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting h3 (from esi-utils-rupture->usgs-libcomcat)
#   Downloading h3-4.4.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (18 kB)
# Collecting setuptools (from obspy>=1.2.1->usgs-libcomcat)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting rtree>=1.0 (from esi-extern-openquake>=1.0.0->esi-utils-rupture->usgs-libcomcat)
#   Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: shapely>=1.8.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from esi-extern-openquake>=1.0.0->esi-utils-rupture->usgs-libcomcat) (2.1.2)
# Collecting beautifulsoup4>=4.11.0 (from esi_utils_time->usgs-libcomcat)
#   Downloading beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4>=4.11.0->esi_utils_time->usgs-libcomcat)
#   Downloading soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyzmq>=19.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from openquake.engine>=3.23->esi-utils-rupture->usgs-libcomcat) (27.1.0)
# Collecting docutils>=0.11 (from openquake.engine>=3.23->esi-utils-rupture->usgs-libcomcat)
#   Downloading docutils-0.22.4-py3-none-any.whl.metadata (15 kB)
# Collecting django<5,>=4.2 (from openquake.engine>=3.23->esi-utils-rupture->usgs-libcomcat)
#   Downloading django-4.2.30-py3-none-any.whl.metadata (4.2 kB)
# Collecting alpha_shapes>=1.1.0 (from openquake.engine>=3.23->esi-utils-rupture->usgs-libcomcat)
#   Downloading alpha_shapes-1.1.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting asgiref<4,>=3.6.0 (from django<5,>=4.2->openquake.engine>=3.23->esi-utils-rupture->usgs-libcomcat)
#   Downloading asgiref-3.11.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting sqlparse>=0.3.1 (from django<5,>=4.2->openquake.engine>=3.23->esi-utils-rupture->usgs-libcomcat)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting llvmlite<0.48,>=0.47.0dev0 (from numba->usgs-libcomcat)
#   Downloading llvmlite-0.47.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.0 kB)
# Collecting pyogrio>=0.7.2 (from geopandas->esi_utils_geo->usgs-libcomcat)
#   Downloading pyogrio-0.12.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Downloading usgs_libcomcat-2.1.12-py3-none-any.whl (976 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.4/976.4 kB 30.3 MB/s  0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Downloading esi_utils_colors-1.0.5-py3-none-any.whl (8.2 kB)
# Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 50.3 MB/s  0:00:006m0:00:01
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Downloading obspy-1.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (15.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 38.3 MB/s  0:00:006m0:00:01
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading sqlalchemy-2.0.49-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 47.3 MB/s  0:00:00
# Downloading greenlet-3.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.4/611.4 kB 21.5 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Downloading esi_utils_geo-0.9.11-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 45.3 MB/s  0:00:006m0:00:01
# Downloading paramiko-4.0.0-py3-none-any.whl (223 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
# Downloading cryptography-48.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 47.4 MB/s  0:00:00
# Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
# Downloading invoke-3.0.3-py3-none-any.whl (160 kB)
# Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 38.3 MB/s  0:00:00
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Downloading scp-0.15.0-py2.py3-none-any.whl (8.8 kB)
# Downloading esi_utils_io-1.1.1-py3-none-any.whl (16 kB)
# Downloading h5py-3.16.0-cp312-cp312-manylinux_2_28_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 42.7 MB/s  0:00:00
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Downloading esi_utils_rupture-1.0.9-py3-none-any.whl (46 kB)
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.3 MB/s  0:00:00
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading esi_extern_openquake-1.0.2-py3-none-any.whl (13 kB)
# Downloading esi_utils_time-1.0.4-py3-none-any.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 27.4 MB/s  0:00:006m0:00:01
# Downloading beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Downloading esi_utils_vectors-1.0.3-py3-none-any.whl (7.3 kB)
# Downloading openquake_engine-3.25.1-py3-none-any.whl (63.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 MB 41.1 MB/s  0:00:016m0:00:0100:01
# Downloading django-4.2.30-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 46.5 MB/s  0:00:00
# Downloading asgiref-3.11.1-py3-none-any.whl (24 kB)
# Downloading alpha_shapes-1.1.1-py3-none-any.whl (8.6 kB)
# Downloading docutils-0.22.4-py3-none-any.whl (633 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.2/633.2 kB 25.1 MB/s  0:00:00
# Downloading h3-4.4.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.0 MB/s  0:00:00
# Downloading numba-0.65.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 46.0 MB/s  0:00:00
# Downloading llvmlite-0.47.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 46.5 MB/s  0:00:016m0:00:01
# Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (507 kB)
# Downloading soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading geopandas-1.1.3-py3-none-any.whl (342 kB)
# Downloading pyogrio-0.12.1-cp312-cp312-manylinux_2_28_x86_64.whl (32.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.5/32.5 MB 45.9 MB/s  0:00:006m0:00:01
# Downloading lxml-6.1.0-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 60.6 MB/s  0:00:00
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pytz, xlsxwriter, urllib3, typing-extensions, toml, sqlparse, soupsieve, setuptools, rtree, pyogrio, pycparser, lxml, llvmlite, invoke, idna, h5py, h3, greenlet, geographiclib, et-xmlfile, docutils, defusedxml, click, charset_normalizer, bcrypt, attrs, asgiref, sqlalchemy, requests, openpyxl, numba, geopy, esi-extern-openquake, django, cligj, click-plugins, cffi, beautifulsoup4, pynacl, obspy, geopandas, fiona, esi-utils-vectors, esi_utils_io, esi_utils_colors, cryptography, alpha_shapes, paramiko, openquake.engine, esi_utils_time, scp, esi-utils-rupture, esi_utils_geo, usgs-libcomcat
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54/54 [usgs-libcomcat]ibcomcat]ils_geo]]e]
# Successfully installed alpha_shapes-1.1.1 asgiref-3.11.1 attrs-26.1.0 bcrypt-5.0.0 beautifulsoup4-4.14.3 cffi-2.0.0 charset_normalizer-3.4.7 click-8.3.3 click-plugins-1.1.1.2 cligj-0.7.2 cryptography-48.0.0 defusedxml-0.7.1 django-4.2.30 docutils-0.22.4 esi-extern-openquake-1.0.2 esi-utils-rupture-1.0.9 esi-utils-vectors-1.0.3 esi_utils_colors-1.0.5 esi_utils_geo-0.9.11 esi_utils_io-1.1.1 esi_utils_time-1.0.4 et-xmlfile-2.0.0 fiona-1.10.1 geographiclib-2.1 geopandas-1.1.3 geopy-2.4.1 greenlet-3.5.0 h3-4.4.2 h5py-3.16.0 idna-3.13 invoke-3.0.3 llvmlite-0.47.0 lxml-6.1.0 numba-0.65.1 obspy-1.5.0 openpyxl-3.1.5 openquake.engine-3.25.1 paramiko-4.0.0 pycparser-3.0 pynacl-1.6.2 pyogrio-0.12.1 pytz-2026.2 requests-2.33.1 rtree-1.4.1 scp-0.15.0 setuptools-81.0.0 soupsieve-2.8.3 sqlalchemy-2.0.49 sqlparse-0.5.5 toml-0.10.2 typing-extensions-4.15.0 urllib3-1.26.20 usgs-libcomcat-2.1.12 xlsxwriter-3.2.9
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install cartopy
# %pip install scikit-learn
# Out:
# Requirement already satisfied: cartopy in /workspaces/PHY386/.venv/lib/python3.12/site-packages (0.25.0)
# Requirement already satisfied: numpy>=1.23 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from cartopy) (2.4.4)
# Requirement already satisfied: matplotlib>=3.6 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from cartopy) (3.10.9)
# Requirement already satisfied: shapely>=2.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from cartopy) (26.2)
# Requirement already satisfied: pyshp>=2.3 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from cartopy) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from pyproj>=3.3.1->cartopy) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /workspaces/PHY386/.venv/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /workspaces/PHY386/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

plt.rcParams.update({
    'font.size': 11, 'axes.labelsize': 11, 'axes.titlesize': 11,
    'xtick.labelsize': 11, 'ytick.labelsize': 11, 'legend.fontsize': 11,
})

# %% [markdown]
# ## Worked Example: Query USGS ComCat
# `libcomcat.search.search` returns a list of event summaries. Each event has `latitude`, `longitude`, `depth` (km), and `magnitude`. We pull five years of M5+ events worldwide — a few thousand rows, comfortable for scikit-learn on a laptop.

# %%
from libcomcat.search import search

events = search(
    starttime=datetime(2020, 1, 1),
    endtime=datetime(2024, 12, 31),
    minmagnitude=5.0,
)
df = pd.DataFrame(
    [{"lat": e.latitude, "lon": e.longitude, "depth": e.depth, "mag": e.magnitude}
     for e in events]
)
print(f"{len(df)} events")
df.head()
# Out:
# 8686 events
#        lat       lon  depth  mag
# 0  -5.3245  152.5514  40.24  5.1
# 1  52.6367  159.1614  58.46  5.0
# 2 -17.4280 -172.5044  10.00  5.4
# 3 -53.0907    9.5001  10.00  5.0
# 4 -30.2857  -71.5582  40.88  5.0

# %% [markdown]
# ## Part 1 — Labeling Ring-of-Fire Membership (8 pts)
#
# ### Task 1.1 — Define a Ring-of-Fire polygon (4 pts)
# Build a simple binary label:
#
# $$\text{ring} = \begin{cases} 1 & \text{if event is in the Pacific Rim region} \\ 0 & \text{otherwise} \end{cases}$$
#
# A coarse polygon is fine. Example rule (adjust if you want a tighter match):
# - Western arm: longitude in [120°E, 180°E] and latitude in [−55°, 60°]
# - Eastern arm: longitude in [−180°, −70°] and latitude in [−55°, 60°]
#
# Remember that longitudes in the data are in [−180°, +180°].
#
# ### Task 1.2 — Visualize the labeling on a world map (4 pts)
# Use `cartopy.crs.PlateCarree()` to plot all events color-coded by label. Sanity-check: does your polygon actually enclose the expected countries (Chile, Peru, Mexico, Japan, Indonesia, New Zealand, …)?

# %%
# Part 1: your code here
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Create a map of the world
fig, ax = plt.subplots(figsize=(10, 5), subplot_kw={'projection': ccrs.PlateCarree()})
ax.add_feature(cfeature.LAND, facecolor='lightgray')

# Define Ring-of-Fire membership
df['ring'] = 0
# Western arm: longitude in [120°E, 180°E] and latitude in [−55°, 60°]
df.loc[(df['lon'] >= 120) & (df['lon'] <= 180) & (df['lat'] >= -55) & (df['lat'] <= 60), 'ring'] = 1
# Eastern arm: longitude in [−180°, −70°] and latitude in [−55°, 60°]
df.loc[(df['lon'] >= -180) & (df['lon'] <= -70) & (df['lat'] >= -55) & (df['lat'] <= 60), 'ring'] = 1

ax.scatter(df['lon'], df['lat'], c=df['ring'], s=4, cmap='RdBu_r',
transform=ccrs.PlateCarree())

# %% [markdown]
# ## Part 2 — Baseline: Geography Only (8 pts)
#
# ### Task 2.1 — k-Nearest Neighbors on (lat, lon) (4 pts)
# Features: `[lat, lon]`. Label: `ring`. Standardize with `StandardScaler`, split 80/20, train a k-Nearest Neighbors classifier with $k$ chosen by simple grid search over {3, 5, 9, 15}. Report accuracy and the confusion matrix on the test set.
#
# ### Task 2.2 — Interpretation (4 pts)
# Why does k-Nearest Neighbors do well here even without depth? What would you expect if you moved to a dataset with different spatial coverage (e.g. M4+ events, which densely sample continental-interior seismicity)?

# %%
# Part 2: your code here

# %% [markdown]
# ## Part 3 — Adding Depth and Magnitude (12 pts)
#
# ### Task 3.1 — Random Forest on (lat, lon, depth, mag) (5 pts)
# Re-train using all four features. Random Forest tolerates mixed scales, so you do not strictly need to standardize, but do it anyway for apples-to-apples comparison with Task 2. Report accuracy + confusion matrix.
#
# ### Task 3.2 — Feature importances (4 pts)
# Plot the Random Forest's `feature_importances_` as a bar chart. Does depth actually help? By how much?
#
# ### Task 3.3 — Depth distribution by class (3 pts)
# Side-by-side histograms of event depth for Ring-of-Fire vs. non-Ring events. Overlay the standard depth ranges:
# - Shallow: 0–70 km
# - Intermediate: 70–300 km
# - Deep: >300 km
#
# Comment on what you see.

# %%
# Part 3: your code here

# %% [markdown]
# ## Part 4 — Decision Regions on the Map (8 pts)
#
# ### Task 4.1 — Dense (lat, lon) grid (3 pts)
# Build a grid of candidate points covering the globe at ~2° resolution.
#
# ### Task 4.2 — Predict and overlay (5 pts)
# For each grid point, predict Ring-of-Fire membership with your k-Nearest Neighbors model (and separately with Random Forest — fix depth and magnitude at their median values). Overlay the predicted region on a `cartopy` world map using semi-transparent filled contours. Add coastlines. Compare the shape to the real Ring-of-Fire.

# %%
# Part 4: your code here

# %% [markdown]
# ## Part 5 — Physics Discussion (6 pts)
#
# Write 5–8 sentences addressing:
# 1. Which feature was most informative — latitude, longitude, depth, or magnitude? Does that match the physics of subduction vs. mid-ocean ridge seismicity?
# 2. Where did your classifier get it wrong? (e.g. the Mediterranean is seismically active but not in the Ring of Fire.)
# 3. If you wanted to recover the Ring-of-Fire *without* the polygon-based labels — i.e. unsupervised — what would you try? (Hint: think DBSCAN or KMeans in (lat, lon, depth) space.)
#
# ### Stretch (optional, bonus 4 pts)
# Download the Bird (2003) tectonic-plate-boundary shapefile and overlay it on your decision-region plot. Comment on which boundary types (convergent, divergent, transform) your classifier captures well vs. poorly.

# %% [markdown]
# ## Submission
# **Good commit** ✅: `Add Random Forest model with depth and magnitude features`
#
# **Bad commit** ❌: `fix`, `stuff`, `done`
#
# ### Checklist
# - [ ] Notebook in `2026/FinalProject/<yourname>/`
# - [ ] Runs top-to-bottom on a fresh kernel
# - [ ] Type annotations and NumPy docstrings on your functions
# - [ ] All plots labeled with units
# - [ ] Tasks sum to ~42 points
# - [ ] PR against `Homework2026`, reviewer `@laserlab`, milestone `Final-2026`
# - [ ] AI usage disclosed in the PR description

# %% [markdown]
# ## Resources
# - [`libcomcat` documentation](https://code.usgs.gov/ghsc/esi/libcomcat-python)
# - [USGS ComCat search parameters](https://earthquake.usgs.gov/fdsnws/event/1/)
# - [Cartopy tutorial](https://scitools.org.uk/cartopy/docs/latest/tutorials/understanding_transform.html)
# - Bird, P. (2003). *An updated digital model of plate boundaries.* Geochem. Geophys. Geosyst., 4(3).
# - PHY386 plotting-style reference: [`2026/handson/ScientificPlottingMatplotlib.ipynb`](../handson/ScientificPlottingMatplotlib.ipynb)
